# %% [markdown]
# # 1. Imports

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display
import pandas as pd
from IPython.display import Audio
import wave, sys

import soundfile as sf
import random

# %% [markdown]
# # 2. Variáveis globais

# %% [markdown]
# # 3. Carregamento e pré-processamento dos dados

# %% [markdown]
# ## 3.1 Diretorias

# %% [markdown]
# ## 3.2. Normalização

# %% [markdown]
# # 4. Feature Extraction

# %% [markdown]
# ## 4.1. Segmentação

# %% [markdown]
# ## 4.2. Extraçao de MFCCs (Mel-Frequency Cepstral Coeffiecients)

# %% [markdown]
# ## 4.3 Data Augmentation

# %% [markdown]
# # 5. Preparação para treino

# %% [markdown]
# ## 6. Treino dos modelos
