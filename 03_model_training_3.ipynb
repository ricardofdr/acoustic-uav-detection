# %% [markdown]
# # 3. Model Training
#
# ## Summary
# Trains DronePrint's **LSTM classifier** (Fig. 8 / Section 4.5.1) - the exact same architecture is
# reused, unmodified, for all three stages of the cascade:
#
# | Classifier | Task | Classes |
# |---|---|---|
# | **X** | Drone detection | `non_drone` / `drone` (+ open-set handling, see §3.5) |
# | **Y** | Make identification | `DJI`, `Parrot`, ... (whichever makes are present) |
# | **Z_<MAKE>** | Model identification within a make | e.g. `Spark`, `MavicPro`, ... |
#
# ### Architecture (Fig. 8)
# Input `(10, 40)` &rarr; 2 stacked LSTM layers (hidden size 32) &rarr; Dense (fully-connected) &rarr;
# Softmax.
#
# ### Training recipe (Section 4.5.1)
# - **Optimizer**: Adam, learning rate **1e-4**
# - **Epochs**: up to **500**
# - **Model selection**: keep the checkpoint with the **lowest validation loss** (we still allow
#   early stopping with a generous patience purely to save compute - the *selection* criterion itself
#   is the paper's, not the stopping criterion)
# - **Inference**: average the softmax probabilities of **3 consecutive windows** (&asymp;6s) and
#   take the arg-max (implemented in notebook 04)
#
# ### Open-set drone detection (Section 4.5.2)
# Classifier X is trained **twice**, with two different open-set strategies, exactly like the paper
# compares them:
# 1. **Background class** - a closed-set binary classifier trained with non-drone sounds (DS2) as an
#    explicit negative class.
# 2. **Modified OpenMax** - a closed-set classifier trained on *drone classes only* (no non-drone
#    data needed at training time), with a class-wise Weibull-calibrated "unknown" rejection layer
#    added at inference time.

# %% [markdown]
# ### Imports

# %%
import os, json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks
from sklearn.utils.class_weight import compute_class_weight

SEED = 42
tf.random.set_seed(SEED)
np.random.seed(SEED)
os.makedirs("plots", exist_ok=True)
os.makedirs("models", exist_ok=True)

print("TensorFlow version:", tf.__version__)
print("GPU available:", bool(tf.config.list_physical_devices('GPU')))
# Out:
# TensorFlow version: 2.21.0
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# GPU available: False

# %% [markdown]
# ## 3.1  The DronePrint LSTM (Fig. 8)
#
# One architecture, reused for every classifier in the cascade. `n_classes` is the only thing that
# changes between X / Y / Z.

# %%
HIDDEN_SIZE = 32        # Fig. 8: "Hidden Unit Size = 32"
N_TIMESTEPS = 10        # Fig. 8: 10 LSTM steps (10 x 200ms frames = 2s)
N_MFCC = 40              # Fig. 8: "40 MFCC features"
LEARNING_RATE = 1e-4     # Section 4.5.1: "Adam optimizer with a learning rate of 0.0001"
MAX_EPOCHS = 500         # Section 4.5.1: "trained ... for 500 epochs"


def build_droneprint_lstm(n_classes: int, input_shape=(N_TIMESTEPS, N_MFCC), hidden_size=HIDDEN_SIZE,
                           name="droneprint_lstm"):
    """
    DronePrint's classifier (Fig. 8): 2 stacked LSTM layers -> Dense -> Softmax.
    Used identically for Classifier X (n_classes=2), Y (n_classes=#makes),
    and each Z_<MAKE> (n_classes=#models in that make).
    """
    inputs = keras.Input(shape=input_shape, name="mfcc_input")
    x = layers.LSTM(hidden_size, return_sequences=True, name="lstm_1")(inputs)
    x = layers.LSTM(hidden_size, return_sequences=False, name="lstm_2")(x)
    outputs = layers.Dense(n_classes, activation="softmax", name="softmax_prediction")(x)
    model = keras.Model(inputs, outputs, name=name)
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    return model


# Quick sanity check of the architecture
_sanity_model = build_droneprint_lstm(n_classes=2)
_sanity_model.summary()
print(f"\nTotal parameters: {_sanity_model.count_params():,}")
del _sanity_model
# Out:
# Model: "droneprint_lstm"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ mfcc_input (InputLayer)         │ (None, 10, 40)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 10, 32)         │         9,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 32)             │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ softmax_prediction (Dense)      │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 17,730 (69.26 KB)
#  Trainable params: 17,730 (69.26 KB)
#  Non-trainable params: 0 (0.00 B)
# Total parameters: 17,730

# %% [markdown]
# ## 3.2  Generic training helper
#
# Trains one LSTM classifier, with `ModelCheckpoint(monitor="val_loss", save_best_only=True)` as the
# model-selection rule the paper describes, plus an early-stopping safety net so we don't always have
# to wait for the full 500 epochs. Class weights are computed automatically to handle any residual
# imbalance (after the balancing already done in notebook 02).

# %%
def train_classifier(name, X_train, y_train, X_val, y_val, n_classes,
                      max_epochs=MAX_EPOCHS, batch_size=32, patience=30):
    """Train one DronePrint-LSTM classifier and return (model, history_df)."""
    print(f"\n{'='*60}\nTraining classifier: {name}   "
          f"(n_classes={n_classes}, train={X_train.shape}, val={X_val.shape})\n{'='*60}")

    model = build_droneprint_lstm(n_classes=n_classes)

    classes = np.unique(y_train)
    weights = compute_class_weight("balanced", classes=classes, y=y_train)
    class_weight = dict(zip(classes.astype(int), weights))
    print("Class weights:", class_weight)

    ckpt_path = f"models/{name}.keras"
    log_path = f"models/{name}_training_log.csv"
    cb_list = [
        callbacks.ModelCheckpoint(ckpt_path, monitor="val_loss", save_best_only=True, verbose=0),
        callbacks.EarlyStopping(monitor="val_loss", patience=patience, restore_best_weights=True, verbose=1),
        callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=patience // 2,
                                     min_lr=1e-7, verbose=0),
        callbacks.CSVLogger(log_path),
    ]

    history = model.fit(
        X_train, y_train,
        validation_data=(X_val, y_val),
        epochs=max_epochs,
        batch_size=batch_size,
        class_weight=class_weight,
        callbacks=cb_list,
        verbose=2,
    )

    # Reload the best checkpoint explicitly (paper: "select the trained model having the lowest
    # validation loss"), in case EarlyStopping's restore_best_weights and the checkpoint disagree.
    best_model = keras.models.load_model(ckpt_path)
    return best_model, history

# %% [markdown]
# ## 3.3  Classifier X - drone detection (background-class method)
#
# The simplest, fully closed-set method: train directly on `drone` vs `non_drone` windows.

# %%
X_train = np.load("X_detect_train.npy")
y_train = np.load("y_detect_train.npy")
X_val   = np.load("X_detect_val.npy")
y_val   = np.load("y_detect_val.npy")
X_test  = np.load("X_detect_test.npy")
y_test  = np.load("y_detect_test.npy")

print(f"X_train {X_train.shape}  X_val {X_val.shape}  X_test {X_test.shape}")

model_X_bg, history_X_bg = train_classifier(
    "classifier_X_background", X_train, y_train, X_val, y_val, n_classes=2)

val_loss, val_acc = model_X_bg.evaluate(X_val, y_val, verbose=0)
print(f"\nClassifier X (background class) - val accuracy: {val_acc*100:.2f}%  val loss: {val_loss:.4f}")
# Out:
# X_train (3549, 10, 40)  X_val (1680, 10, 40)  X_test (98, 10, 40)
#
# ============================================================
# Training classifier: classifier_X_background   (n_classes=2, train=(3549, 10, 40), val=(1680, 10, 40))
# ============================================================
# Class weights: {np.int64(0): np.float64(0.6259259259259259), np.int64(1): np.float64(2.485294117647059)}
# Epoch 1/500
# 111/111 - 2s - 19ms/step - accuracy: 0.8225 - loss: 0.6677 - val_accuracy: 0.8071 - val_loss: 0.6259 - learning_rate: 1.0000e-04
# Epoch 2/500
# 111/111 - 0s - 4ms/step - accuracy: 0.9797 - loss: 0.5071 - val_accuracy: 0.9518 - val_loss: 0.3110 - learning_rate: 1.0000e-04
# Epoch 3/500
# 111/111 - 0s - 4ms/step - accuracy: 0.9975 - loss: 0.1318 - val_accuracy: 0.9946 - val_loss: 0.0571 - learning_rate: 1.0000e-04
# Epoch 4/500
# 111/111 - 0s - 4ms/step - accuracy: 0.9977 - loss: 0.0265 - val_accuracy: 0.9982 - val_loss: 0.0234 - learning_rate: 1.0000e-04
# Epoch 5/500
# 111/111 - 0s - 4ms/step - accuracy: 0.9992 - loss: 0.0118 - val_accuracy: 0.9988 - val_loss: 0.0140 - learning_rate: 1.0000e-04
# Epoch 6/500
# 111/111 - 0s - 4ms/step - accuracy: 0.9994 - loss: 0.0068 - val_accuracy: 0.9994 - val_loss: 0.0100 - learning_rate: 1.0000e-04
# Epoch 7/500
# 111/111 - 0s - 4ms/step - accuracy: 0.9997 - loss: 0.0044 - val_accuracy: 0.9994 - val_loss: 0.0084 - learning_rate: 1.0000e-04
# Epoch 8/500
# 111/111 - 1s - 5ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.9982 - val_loss: 0.0081 - learning_rate: 1.0000e-04
# Epoch 9/500
# 111/111 - 1s - 5ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9982 - val_loss: 0.0084 - learning_rate: 1.0000e-04
# Epoch 10/500
# 111/111 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9976 - val_loss: 0.0088 - learning_rate: 1.0000e-04
# Epoch 11/500
# 111/111 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.9976 - val_loss: 0.0091 - learning_rate: 1.0000e-04
# Epoch 12/500
# 111/111 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.9970 - val_loss: 0.0092 - learning_rate: 1.0000e-04
# Epoch 13/500
# 111/111 - 0s - 4ms/step - accuracy: 1.0000 - loss: 8.2473e-04 - val_accuracy: 0.9970 - val_loss: 0.0092 - learning_rate: 1.0000e-04
# Epoch 14/500
# 111/111 - 0s - 4ms/step - accuracy: 1.0000 - loss: 6.7168e-04 - val_accuracy: 0.9970 - val_loss: 0.0092 - learning_rate: 1.0000e-04
# Epoch 15/500
# 111/111 - 0s - 4ms/step - accuracy: 1.0000 - loss: 5.5781e-04 - val_accuracy: 0.9970 - val_loss: 0.0093 - learning_rate: 1.0000e-04
# Epoch 16/500
# 111/111 - 0s - 4ms/step - accuracy: 1.0000 - loss: 4.7182e-04 - val_accuracy: 0.9970 - val_loss: 0.0093 - learning_rate: 1.0000e-04
# Epoch 17/500
# 111/111 - 0s - 4ms/step - accuracy: 1.0000 - loss: 4.0533e-04 - val_accuracy: 0.9970 - val_loss: 0.0094 - learning_rate: 1.0000e-04
# Epoch 18/500
# 111/111 - 0s - 4ms/step - accuracy: 1.0000 - loss: 3.5268e-04 - val_accuracy: 0.9970 - val_loss: 0.0096 - learning_rate: 1.0000e-04
# Epoch 19/500
# 111/111 - 0s - 4ms/step - accuracy: 1.0000 - loss: 3.1011e-04 - val_accuracy: 0.9970 - val_loss: 0.0097 - learning_rate: 1.0000e-04
# Epoch 20/500
# 111/111 - 0s - 4ms/step - accuracy: 1.0000 - loss: 2.7507e-04 - val_accuracy: 0.9970 - val_loss: 0.0099 - learning_rate: 1.0000e-04
# Epoch 21/500
# 111/111 - 0s - 4ms/step - accuracy: 1.0000 - loss: 2.4581e-04 - val_accuracy: 0.9970 - val_loss: 0.0101 - learning_rate: 1.0000e-04
# Epoch 22/500
# 111/111 - 0s - 4ms/step - accuracy: 1.0000 - loss: 2.2106e-04 - val_accuracy: 0.9970 - val_loss: 0.0103 - learning_rate: 1.0000e-04
# Epoch 23/500
# 111/111 - 0s - 4ms/step - accuracy: 1.0000 - loss: 1.9989e-04 - val_accuracy: 0.9970 - val_loss: 0.0105 - learning_rate: 1.0000e-04
# Epoch 24/500
# 111/111 - 0s - 4ms/step - accuracy: 1.0000 - loss: 1.8392e-04 - val_accuracy: 0.9970 - val_loss: 0.0104 - learning_rate: 5.0000e-05
# Epoch 25/500
# 111/111 - 0s - 4ms/step - accuracy: 1.0000 - loss: 1.7536e-04 - val_accuracy: 0.9970 - val_loss: 0.0104 - learning_rate: 5.0000e-05
# Epoch 26/500
# 111/111 - 0s - 4ms/step - accuracy: 1.0000 - loss: 1.6729e-04 - val_accuracy: 0.9970 - val_loss: 0.0105 - learning_rate: 5.0000e-05
# Epoch 27/500
# 111/111 - 0s - 4ms/step - accuracy: 1.0000 - loss: 1.5955e-04 - val_accuracy: 0.9970 - val_loss: 0.0106 - learning_rate: 5.0000e-05
# Epoch 28/500
# 111/111 - 0s - 4ms/step - accuracy: 1.0000 - loss: 1.5214e-04 - val_accuracy: 0.9970 - val_loss: 0.0108 - learning_rate: 5.0000e-05
# Epoch 29/500
# 111/111 - 0s - 4ms/step - accuracy: 1.0000 - loss: 1.4504e-04 - val_accuracy: 0.9970 - val_loss: 0.0109 - learning_rate: 5.0000e-05
# Epoch 30/500
# 111/111 - 0s - 4ms/step - accuracy: 1.0000 - loss: 1.3823e-04 - val_accuracy: 0.9970 - val_loss: 0.0111 - learning_rate: 5.0000e-05
# Epoch 31/500
# 111/111 - 0s - 4ms/step - accuracy: 1.0000 - loss: 1.3172e-04 - val_accuracy: 0.9970 - val_loss: 0.0112 - learning_rate: 5.0000e-05
# Epoch 32/500
# 111/111 - 0s - 4ms/step - accuracy: 1.0000 - loss: 1.2549e-04 - val_accuracy: 0.9970 - val_loss: 0.0114 - learning_rate: 5.0000e-05
# Epoch 33/500
# 111/111 - 0s - 4ms/step - accuracy: 1.0000 - loss: 1.1954e-04 - val_accuracy: 0.9970 - val_loss: 0.0115 - learning_rate: 5.0000e-05
# Epoch 34/500
# 111/111 - 0s - 4ms/step - accuracy: 1.0000 - loss: 1.1386e-04 - val_accuracy: 0.9970 - val_loss: 0.0117 - learning_rate: 5.0000e-05
# Epoch 35/500
# 111/111 - 0s - 4ms/step - accuracy: 1.0000 - loss: 1.0843e-04 - val_accuracy: 0.9970 - val_loss: 0.0119 - learning_rate: 5.0000e-05
# Epoch 36/500
# 111/111 - 0s - 4ms/step - accuracy: 1.0000 - loss: 1.0326e-04 - val_accuracy: 0.9970 - val_loss: 0.0120 - learning_rate: 5.0000e-05
# Epoch 37/500
# 111/111 - 0s - 4ms/step - accuracy: 1.0000 - loss: 9.8322e-05 - val_accuracy: 0.9970 - val_loss: 0.0122 - learning_rate: 5.0000e-05
# Epoch 38/500
# 111/111 - 0s - 4ms/step - accuracy: 1.0000 - loss: 9.3618e-05 - val_accuracy: 0.9970 - val_loss: 0.0124 - learning_rate: 5.0000e-05
# Epoch 38: early stopping
# Restoring model weights from the end of the best epoch: 8.
#
# Classifier X (background class) - val accuracy: 99.82%  val loss: 0.0081

# %% [markdown]
# ## 3.4  Training curves - Classifier X (background class)

# %%
log_bg = pd.read_csv("models/classifier_X_background_training_log.csv")

fig, axes = plt.subplots(1, 2, figsize=(13, 4))
for ax, col, title in zip(axes, ["loss", "accuracy"], ["Loss", "Accuracy"]):
    ax.plot(log_bg["epoch"] + 1, log_bg[col], label="train", linewidth=2)
    ax.plot(log_bg["epoch"] + 1, log_bg[f"val_{col}"], label="val", linewidth=2, linestyle="--")
    ax.set_title(f"Classifier X (background class) - {title}", fontweight="bold")
    ax.set_xlabel("Epoch"); ax.legend(); ax.grid(alpha=0.3)
plt.tight_layout()
plt.savefig("plots/classifier_X_background_curves.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# ## 3.5  Classifier X - drone detection (modified OpenMax method)
#
# Section 4.5.2: trains a **closed-set, drone-classes-only** classifier (no non-drone data needed at
# training time), then calibrates a class-wise Weibull "unknown" rejection model on top of its
# penultimate-layer activations. This is the "Modified OpenMax" from the paper: per-class thresholds
# instead of one single global threshold, on top of the original OpenMax algorithm (Bendale & Boult,
# 2016).

# %%
# OpenMax needs a *closed-set, drone-only* classifier (no background class) that covers
# EVERY known drone (make, model) pair - not just the makes that happen to have a Z classifier.
#
# BUGFIX (vs. the previous version of this cell): the earlier version used *only* the Z_<MAKE>
# .npy files as the closed set whenever at least one existed. With your current data that meant
# the closed set was built from Z_DJI alone (4 DJI models) and Parrot was silently dropped
# entirely - so every Parrot test window had no matching class to be recognised as, and OpenMax
# rejected it as "not a drone" by default. That's almost certainly why OpenMax scored only ~54%
# while the background-class method scored ~96% on the same test set: half the drone makes were
# invisible to OpenMax's closed set.
#
# Fixed approach: for every make in make_label_encoder.json, use its dedicated Z_<MAKE> dataset
# (one class per model) if it exists; otherwise fall back to that make's own make-level windows
# from X_make_*.npy as a single class (a make with only one model IS that one model).
import glob

make_classes_list = json.load(open("make_label_encoder.json"))["classes"]
X_make_train_all = np.load("X_make_train.npy"); y_make_train_all = np.load("y_make_train.npy")
X_make_val_all   = np.load("X_make_val.npy");   y_make_val_all   = np.load("y_make_val.npy")

openmax_classes = []     # list of "MAKE::MODEL" strings, index = global class id
X_om_train_list, y_om_train_list = [], []
X_om_val_list, y_om_val_list = [], []

for make_idx, make_name in enumerate(make_classes_list):
    z_train_path = f"X_model_{make_name}_train.npy"
    if os.path.exists(z_train_path):
        # Multi-model make -> one OpenMax class per model, via its dedicated Z_<MAKE> dataset.
        enc = json.load(open(f"model_label_encoder_{make_name}.json"))["classes"]
        offset = len(openmax_classes)
        openmax_classes.extend([f"{make_name}::{m}" for m in enc])

        Xtr = np.load(z_train_path); ytr = np.load(f"y_model_{make_name}_train.npy")
        Xv  = np.load(f"X_model_{make_name}_val.npy");   yv  = np.load(f"y_model_{make_name}_val.npy")
        X_om_train_list.append(Xtr); y_om_train_list.append(ytr + offset)
        X_om_val_list.append(Xv);    y_om_val_list.append(yv + offset)
    else:
        # Single-model make -> treat the whole make as one OpenMax class.
        offset = len(openmax_classes)
        openmax_classes.append(f"{make_name}::(single model)")
        mask_tr = (y_make_train_all == make_idx)
        mask_v  = (y_make_val_all == make_idx)
        X_om_train_list.append(X_make_train_all[mask_tr]); y_om_train_list.append(np.full(mask_tr.sum(), offset))
        X_om_val_list.append(X_make_val_all[mask_v]);       y_om_val_list.append(np.full(mask_v.sum(), offset))

X_om_train = np.concatenate(X_om_train_list); y_om_train = np.concatenate(y_om_train_list)
X_om_val   = np.concatenate(X_om_val_list);   y_om_val   = np.concatenate(y_om_val_list)

print(f"OpenMax closed-set classes ({len(openmax_classes)}): {openmax_classes}")
print(f"X_om_train {X_om_train.shape}  X_om_val {X_om_val.shape}")

model_X_om, history_X_om = train_classifier(
    "classifier_X_openmax_closed_set", X_om_train, y_om_train, X_om_val, y_om_val,
    n_classes=len(openmax_classes))
# Out:
# OpenMax closed-set classes (5): ['DJI::Matrice100', 'DJI::MavicPro', 'DJI::Phantom4Pro', 'DJI::Spark', 'Parrot::(single model)']
# X_om_train (1785, 10, 40)  X_om_val (840, 10, 40)
#
# ============================================================
# Training classifier: classifier_X_openmax_closed_set   (n_classes=5, train=(1785, 10, 40), val=(840, 10, 40))
# ============================================================
# Class weights: {np.int64(0): np.float64(1.2142857142857142), np.int64(1): np.float64(1.2142857142857142), np.int64(2): np.float64(1.2142857142857142), np.int64(3): np.float64(1.2142857142857142), np.int64(4): np.float64(0.5862068965517241)}
# Epoch 1/500
# 56/56 - 2s - 33ms/step - accuracy: 0.3888 - loss: 1.5841 - val_accuracy: 0.6405 - val_loss: 1.5663 - learning_rate: 1.0000e-04
# Epoch 2/500
# 56/56 - 0s - 5ms/step - accuracy: 0.7025 - loss: 1.5437 - val_accuracy: 0.6893 - val_loss: 1.5272 - learning_rate: 1.0000e-04
# Epoch 3/500
# 56/56 - 0s - 5ms/step - accuracy: 0.7966 - loss: 1.4816 - val_accuracy: 0.6881 - val_loss: 1.4607 - learning_rate: 1.0000e-04
# Epoch 4/500
# 56/56 - 0s - 5ms/step - accuracy: 0.8062 - loss: 1.3676 - val_accuracy: 0.6869 - val_loss: 1.3366 - learning_rate: 1.0000e-04
# Epoch 5/500
# 56/56 - 0s - 4ms/step - accuracy: 0.7983 - loss: 1.1591 - val_accuracy: 0.6821 - val_loss: 1.1225 - learning_rate: 1.0000e-04
# Epoch 6/500
# 56/56 - 0s - 5ms/step - accuracy: 0.7843 - loss: 0.8614 - val_accuracy: 0.7452 - val_loss: 0.8257 - learning_rate: 1.0000e-04
# Epoch 7/500
# 56/56 - 0s - 5ms/step - accuracy: 0.8650 - loss: 0.5687 - val_accuracy: 0.8512 - val_loss: 0.6008 - learning_rate: 1.0000e-04
# Epoch 8/500
# 56/56 - 0s - 5ms/step - accuracy: 0.9602 - loss: 0.3639 - val_accuracy: 0.8571 - val_loss: 0.5125 - learning_rate: 1.0000e-04
# Epoch 9/500
# 56/56 - 0s - 4ms/step - accuracy: 0.9882 - loss: 0.2268 - val_accuracy: 0.8405 - val_loss: 0.4743 - learning_rate: 1.0000e-04
# Epoch 10/500
# 56/56 - 0s - 5ms/step - accuracy: 0.9972 - loss: 0.1398 - val_accuracy: 0.8286 - val_loss: 0.4626 - learning_rate: 1.0000e-04
# Epoch 11/500
# 56/56 - 0s - 4ms/step - accuracy: 0.9978 - loss: 0.0926 - val_accuracy: 0.8274 - val_loss: 0.4679 - learning_rate: 1.0000e-04
# Epoch 12/500
# 56/56 - 0s - 5ms/step - accuracy: 0.9989 - loss: 0.0664 - val_accuracy: 0.8262 - val_loss: 0.4833 - learning_rate: 1.0000e-04
# Epoch 13/500
# 56/56 - 0s - 4ms/step - accuracy: 0.9994 - loss: 0.0505 - val_accuracy: 0.8262 - val_loss: 0.4995 - learning_rate: 1.0000e-04
# Epoch 14/500
# 56/56 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0401 - val_accuracy: 0.8262 - val_loss: 0.5124 - learning_rate: 1.0000e-04
# Epoch 15/500
# 56/56 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.0329 - val_accuracy: 0.8250 - val_loss: 0.5229 - learning_rate: 1.0000e-04
# Epoch 16/500
# 56/56 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.0278 - val_accuracy: 0.8298 - val_loss: 0.5326 - learning_rate: 1.0000e-04
# Epoch 17/500
# 56/56 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0239 - val_accuracy: 0.8321 - val_loss: 0.5423 - learning_rate: 1.0000e-04
# Epoch 18/500
# 56/56 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0209 - val_accuracy: 0.8333 - val_loss: 0.5516 - learning_rate: 1.0000e-04
# Epoch 19/500
# 56/56 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.0186 - val_accuracy: 0.8321 - val_loss: 0.5600 - learning_rate: 1.0000e-04
# Epoch 20/500
# 56/56 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0166 - val_accuracy: 0.8345 - val_loss: 0.5674 - learning_rate: 1.0000e-04
# Epoch 21/500
# 56/56 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0150 - val_accuracy: 0.8393 - val_loss: 0.5740 - learning_rate: 1.0000e-04
# Epoch 22/500
# 56/56 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0136 - val_accuracy: 0.8381 - val_loss: 0.5803 - learning_rate: 1.0000e-04
# Epoch 23/500
# 56/56 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 0.8381 - val_loss: 0.5866 - learning_rate: 1.0000e-04
# Epoch 24/500
# 56/56 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0115 - val_accuracy: 0.8393 - val_loss: 0.5928 - learning_rate: 1.0000e-04
# Epoch 25/500
# 56/56 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0106 - val_accuracy: 0.8393 - val_loss: 0.5990 - learning_rate: 1.0000e-04
# Epoch 26/500
# 56/56 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 0.8381 - val_loss: 0.6048 - learning_rate: 5.0000e-05
# Epoch 27/500
# 56/56 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0097 - val_accuracy: 0.8381 - val_loss: 0.6080 - learning_rate: 5.0000e-05
# Epoch 28/500
# 56/56 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0093 - val_accuracy: 0.8381 - val_loss: 0.6109 - learning_rate: 5.0000e-05
# Epoch 29/500
# 56/56 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0090 - val_accuracy: 0.8381 - val_loss: 0.6138 - learning_rate: 5.0000e-05
# Epoch 30/500
# 56/56 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0087 - val_accuracy: 0.8405 - val_loss: 0.6167 - learning_rate: 5.0000e-05
# Epoch 31/500
# 56/56 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.8405 - val_loss: 0.6197 - learning_rate: 5.0000e-05
# Epoch 32/500
# 56/56 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0081 - val_accuracy: 0.8393 - val_loss: 0.6226 - learning_rate: 5.0000e-05
# Epoch 33/500
# 56/56 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.8393 - val_loss: 0.6256 - learning_rate: 5.0000e-05
# Epoch 34/500
# 56/56 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0075 - val_accuracy: 0.8405 - val_loss: 0.6286 - learning_rate: 5.0000e-05
# Epoch 35/500
# 56/56 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 0.8405 - val_loss: 0.6316 - learning_rate: 5.0000e-05
# Epoch 36/500
# 56/56 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0070 - val_accuracy: 0.8405 - val_loss: 0.6346 - learning_rate: 5.0000e-05
# Epoch 37/500
# 56/56 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.8405 - val_loss: 0.6377 - learning_rate: 5.0000e-05
# Epoch 38/500
# 56/56 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.8405 - val_loss: 0.6407 - learning_rate: 5.0000e-05
# Epoch 39/500
# 56/56 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.8405 - val_loss: 0.6438 - learning_rate: 5.0000e-05
# Epoch 40/500
# 56/56 - 0s - 4ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 0.8405 - val_loss: 0.6469 - learning_rate: 5.0000e-05
# Epoch 40: early stopping
# Restoring model weights from the end of the best epoch: 10.

# %% [markdown]
# ### 3.5.1  OpenMax calibration
#
# A compact, dependency-free re-implementation of OpenMax (Bendale & Boult, CVPR 2016), modified per
# DronePrint Section 4.5.2 with **per-class thresholds** instead of one global threshold:
#
# 1. For every known class, collect the penultimate-layer activation vectors of its *correctly
#    classified* training samples.
# 2. Compute each class's Mean Activation Vector (MAV).
# 3. Fit a Weibull distribution to the largest &eta; Euclidean distances from the MAV (the "tail" -
#    Extreme Value Theory says the tail of correctly-classified-sample distances is Weibull-shaped).
# 4. At inference: compute the new sample's activation vector, get its Weibull CDF distance score per
#    class, revise (shrink) the top-&alpha; logits accordingly and route the removed probability mass
#    into a new "unknown" logit, then re-softmax.
# 5. Tune one **acceptance threshold per known class** on the validation set.

# %%
from scipy.stats import weibull_min

PENULTIMATE_LAYER_NAME = "lstm_2"   # output of the 2nd LSTM layer = the penultimate (pre-softmax) features


def get_activation_extractor(model, layer_name=PENULTIMATE_LAYER_NAME):
    return keras.Model(model.input, model.get_layer(layer_name).output)


def fit_openmax_weibull(model, X_train, y_train, n_classes, tail_size=20):
    """Fit one Weibull tail model per class on correctly-classified training activations."""
    extractor = get_activation_extractor(model)
    activations = extractor.predict(X_train, batch_size=128, verbose=0)
    preds = model.predict(X_train, batch_size=128, verbose=0).argmax(axis=1)

    weibull_params = {}   # class -> (mav, shape_c, loc, scale)
    for c in range(n_classes):
        correct_mask = (y_train == c) & (preds == c)
        acts_c = activations[correct_mask]
        if len(acts_c) < max(tail_size, 3):
            print(f"  [warn] class {c}: only {len(acts_c)} correctly-classified training samples "
                  f"(<{tail_size}) - Weibull fit may be unstable.")
        if len(acts_c) == 0:
            weibull_params[c] = None
            continue
        mav = acts_c.mean(axis=0)
        dists = np.linalg.norm(acts_c - mav, axis=1)
        tail = np.sort(dists)[-min(tail_size, len(dists)):]
        try:
            shape_c, loc, scale = weibull_min.fit(tail, floc=0)
        except Exception:
            shape_c, loc, scale = 1.0, 0.0, max(tail.mean(), 1e-6)
        weibull_params[c] = (mav, shape_c, loc, scale)
    return weibull_params, extractor


def openmax_recalibrate(logits, activation, weibull_params, n_classes, alpha=None):
    """
    Revise raw (pre-softmax) `logits` for one sample using its penultimate `activation` vector.
    Returns a probability vector of length n_classes+1 (last entry = 'unknown').
    """
    if alpha is None:
        alpha = n_classes  # revise all known classes, as in the original OpenMax paper

    ranked = np.argsort(-logits)[:alpha]
    revised = logits.copy()
    unknown_logit = 0.0
    for rank, c in enumerate(ranked):
        params = weibull_params.get(c)
        if params is None:
            continue
        mav, shape_c, loc, scale = params
        dist = np.linalg.norm(activation - mav)
        w_score = weibull_min.cdf(dist, shape_c, loc=loc, scale=scale)
        omega = ((alpha - rank) / alpha) * w_score   # linear rank-weighting, as in the OpenMax paper
        revised[c] = logits[c] * (1 - omega)
        unknown_logit += logits[c] * omega

    full_logits = np.append(revised, unknown_logit)
    exp_l = np.exp(full_logits - full_logits.max())
    probs = exp_l / exp_l.sum()
    return probs   # length n_classes + 1


print("OpenMax helper functions ready.")
# Out:
# OpenMax helper functions ready.

# %%
weibull_params, activation_extractor = fit_openmax_weibull(
    model_X_om, X_om_train, y_om_train, n_classes=len(openmax_classes), tail_size=20)

# Save Weibull params (numpy floats -> plain floats so json can serialise them)
weibull_serializable = {
    str(c): (None if v is None else {
        "mav": v[0].tolist(), "shape": float(v[1]), "loc": float(v[2]), "scale": float(v[3])
    })
    for c, v in weibull_params.items()
}
with open("models/openmax_weibull_params.json", "w") as f:
    json.dump({"classes": openmax_classes, "params": weibull_serializable}, f)
print(f"Fitted Weibull tails for {len(weibull_params)} classes.")
# Out:
# Fitted Weibull tails for 5 classes.

# %% [markdown]
# ### 3.5.2  Per-class threshold tuning (Section 4.5.2)
#
# > *"we assign a separate threshold value for each known class"*
#
# For every known class we sweep a threshold on the OpenMax-revised "is this really class c, or is it
# unknown?" score, using the validation set (drone windows of that class = positive, everything else
# in the validation set = negative-for-this-class), and keep the threshold that maximises F1 for that
# class.

# %%
def openmax_predict_batch(model, extractor, weibull_params, X, n_classes):
    # The model's final Dense layer already applies softmax (no raw logits available), so we
    # approximate logits via log of the softmax probabilities (monotonic, rank-preserving stand-in).
    probs_softmax = model.predict(X, batch_size=128, verbose=0)
    pseudo_logits = np.log(np.clip(probs_softmax, 1e-8, 1.0))
    activations = extractor.predict(X, batch_size=128, verbose=0)

    out = np.zeros((len(X), n_classes + 1))
    for i in range(len(X)):
        out[i] = openmax_recalibrate(pseudo_logits[i], activations[i], weibull_params, n_classes)
    return out  # (N, n_classes+1), last column = P(unknown)


def openmax_decide(probs, thresholds_by_class, classes):
    """
    Correct OpenMax decision rule (Section 4.5.2): take the predicted class as the arg-max over
    ALL n_classes+1 entries (including the 'unknown' bucket). If 'unknown' wins, reject outright.
    Otherwise, the predicted KNOWN class must still clear *its own* threshold to be accepted -
    this is NOT "does any class clear its own threshold" (that was the bug in the previous version
    of this notebook: with several moderate per-class thresholds, almost every input - drone or
    not - had at least one class edge over its bar, so nearly everything got flagged 'drone').
    """
    n_classes = len(classes)
    predicted_idx = probs.argmax(axis=1)               # 0..n_classes (n_classes == 'unknown')
    is_known = predicted_idx < n_classes
    thresh_per_row = np.array([thresholds_by_class[classes[c]] if c < n_classes else np.inf
                                for c in predicted_idx])
    prob_of_predicted = probs[np.arange(len(probs)), predicted_idx]
    accepted = is_known & (prob_of_predicted >= thresh_per_row)
    predicted_class = np.where(accepted, predicted_idx, -1)   # -1 = rejected / unknown
    return accepted, predicted_class


# BUGFIX: the previous version of this cell tuned thresholds using ONLY drone-class validation
# windows (X_om_val) - it never saw what a genuine non-drone sound's OpenMax output looks like.
# Combined with the old "any class clears its threshold" decision rule, that meant the tuned
# thresholds had no way to learn to reject non-drone audio at all. We now pull in the non-drone
# validation windows from Classifier X's own validation split (DS2 background sounds) as explicit
# negatives, and tune thresholds against the *argmax-gated* decision rule above (the one actually
# used at inference time), not an isolated per-class F1 that ignores which class was predicted.
X_detect_val_full = np.load("X_detect_val.npy")
y_detect_val_full = np.load("y_detect_val.npy")
X_nondrone_val = X_detect_val_full[y_detect_val_full == 0]
print(f"Non-drone validation windows available for threshold tuning: {X_nondrone_val.shape}")

probs_val_drone = openmax_predict_batch(model_X_om, activation_extractor, weibull_params,
                                         X_om_val, n_classes=len(openmax_classes))
probs_val_nondrone = openmax_predict_batch(model_X_om, activation_extractor, weibull_params,
                                            X_nondrone_val, n_classes=len(openmax_classes))

val_om_probs_full = np.concatenate([probs_val_drone, probs_val_nondrone])
# Sentinel label -1 for "this is truly not any known drone class" (genuine non-drone audio).
val_true_full = np.concatenate([y_om_val, np.full(len(X_nondrone_val), -1)])

class_thresholds = {}
thresholds_grid = np.linspace(0.05, 0.95, 37)
predicted_idx_full = val_om_probs_full.argmax(axis=1)

for c in range(len(openmax_classes)):
    is_class_c = (val_true_full == c)
    predicted_as_c = (predicted_idx_full == c)
    p_c = val_om_probs_full[:, c]
    best_t, best_f1 = 0.5, -1
    for t in thresholds_grid:
        accepted_as_c = predicted_as_c & (p_c >= t)
        tp = np.sum(accepted_as_c & is_class_c)
        fp = np.sum(accepted_as_c & ~is_class_c)
        fn = np.sum(~accepted_as_c & is_class_c)
        f1 = 2 * tp / (2 * tp + fp + fn) if (2 * tp + fp + fn) > 0 else 0.0
        if f1 > best_f1:
            best_f1, best_t = f1, t
    class_thresholds[openmax_classes[c]] = float(best_t)
    print(f"  {openmax_classes[c]:>24s}  threshold={best_t:.2f}  val F1={best_f1:.3f}")

# Sanity check: with the fixed decision rule, how many of the non-drone validation windows now
# get correctly rejected as unknown?
_, pred_class_nondrone = openmax_decide(probs_val_nondrone, class_thresholds, openmax_classes)
rejection_rate = float((pred_class_nondrone == -1).mean())
print(f"\nNon-drone validation windows correctly rejected as 'unknown': {rejection_rate*100:.1f}%")

with open("models/openmax_class_thresholds.json", "w") as f:
    json.dump(class_thresholds, f, indent=2)
# Out:
# Non-drone validation windows available for threshold tuning: (945, 10, 40)
#            DJI::Matrice100  threshold=0.42  val F1=0.391
#              DJI::MavicPro  threshold=0.45  val F1=0.632
#           DJI::Phantom4Pro  threshold=0.50  val F1=0.991
#                 DJI::Spark  threshold=0.05  val F1=1.000
#     Parrot::(single model)  threshold=0.35  val F1=0.738
#
# Non-drone validation windows correctly rejected as 'unknown': 91.3%

# %% [markdown]
# ## 3.6  Classifier Y - drone make identification

# %%
X_make_train = np.load("X_make_train.npy"); y_make_train = np.load("y_make_train.npy")
X_make_val   = np.load("X_make_val.npy");   y_make_val   = np.load("y_make_val.npy")
make_classes = json.load(open("make_label_encoder.json"))["classes"]

print(f"Make classes: {make_classes}")
model_Y, history_Y = train_classifier(
    "classifier_Y_make", X_make_train, y_make_train, X_make_val, y_make_val,
    n_classes=len(make_classes))

val_loss, val_acc = model_Y.evaluate(X_make_val, y_make_val, verbose=0)
print(f"\nClassifier Y - val accuracy: {val_acc*100:.2f}%  val loss: {val_loss:.4f}")
# Out:
# Make classes: ['DJI', 'Parrot']
#
# ============================================================
# Training classifier: classifier_Y_make   (n_classes=2, train=(1218, 10, 40), val=(840, 10, 40))
# ============================================================
# Class weights: {np.int64(0): np.float64(1.0), np.int64(1): np.float64(1.0)}
# Epoch 1/500
# 39/39 - 2s - 48ms/step - accuracy: 0.7167 - loss: 0.6741 - val_accuracy: 0.7524 - val_loss: 0.6709 - learning_rate: 1.0000e-04
# Epoch 2/500
# 39/39 - 0s - 6ms/step - accuracy: 0.7693 - loss: 0.6544 - val_accuracy: 0.7798 - val_loss: 0.6530 - learning_rate: 1.0000e-04
# Epoch 3/500
# 39/39 - 0s - 6ms/step - accuracy: 0.8424 - loss: 0.6263 - val_accuracy: 0.7905 - val_loss: 0.6248 - learning_rate: 1.0000e-04
# Epoch 4/500
# 39/39 - 0s - 6ms/step - accuracy: 0.8924 - loss: 0.5794 - val_accuracy: 0.8226 - val_loss: 0.5763 - learning_rate: 1.0000e-04
# Epoch 5/500
# 39/39 - 0s - 6ms/step - accuracy: 0.9261 - loss: 0.4984 - val_accuracy: 0.8476 - val_loss: 0.4961 - learning_rate: 1.0000e-04
# Epoch 6/500
# 39/39 - 0s - 8ms/step - accuracy: 0.9302 - loss: 0.3745 - val_accuracy: 0.8583 - val_loss: 0.3936 - learning_rate: 1.0000e-04
# Epoch 7/500
# 39/39 - 0s - 8ms/step - accuracy: 0.9516 - loss: 0.2393 - val_accuracy: 0.8857 - val_loss: 0.3053 - learning_rate: 1.0000e-04
# Epoch 8/500
# 39/39 - 0s - 9ms/step - accuracy: 0.9967 - loss: 0.1319 - val_accuracy: 0.8964 - val_loss: 0.2524 - learning_rate: 1.0000e-04
# Epoch 9/500
# 39/39 - 0s - 8ms/step - accuracy: 0.9951 - loss: 0.0670 - val_accuracy: 0.8929 - val_loss: 0.2496 - learning_rate: 1.0000e-04
# Epoch 10/500
# 39/39 - 0s - 8ms/step - accuracy: 0.9992 - loss: 0.0367 - val_accuracy: 0.8869 - val_loss: 0.2768 - learning_rate: 1.0000e-04
# Epoch 11/500
# 39/39 - 0s - 8ms/step - accuracy: 0.9992 - loss: 0.0223 - val_accuracy: 0.8821 - val_loss: 0.3110 - learning_rate: 1.0000e-04
# Epoch 12/500
# 39/39 - 0s - 7ms/step - accuracy: 0.9992 - loss: 0.0148 - val_accuracy: 0.8810 - val_loss: 0.3469 - learning_rate: 1.0000e-04
# Epoch 13/500
# 39/39 - 0s - 8ms/step - accuracy: 0.9992 - loss: 0.0106 - val_accuracy: 0.8786 - val_loss: 0.3822 - learning_rate: 1.0000e-04
# Epoch 14/500
# 39/39 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.8750 - val_loss: 0.4140 - learning_rate: 1.0000e-04
# Epoch 15/500
# 39/39 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0063 - val_accuracy: 0.8702 - val_loss: 0.4415 - learning_rate: 1.0000e-04
# Epoch 16/500
# 39/39 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.0052 - val_accuracy: 0.8679 - val_loss: 0.4653 - learning_rate: 1.0000e-04
# Epoch 17/500
# 39/39 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.8667 - val_loss: 0.4862 - learning_rate: 1.0000e-04
# Epoch 18/500
# 39/39 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.8655 - val_loss: 0.5049 - learning_rate: 1.0000e-04
# Epoch 19/500
# 39/39 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.0032 - val_accuracy: 0.8643 - val_loss: 0.5220 - learning_rate: 1.0000e-04
# Epoch 20/500
# 39/39 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.8631 - val_loss: 0.5377 - learning_rate: 1.0000e-04
# Epoch 21/500
# 39/39 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.8631 - val_loss: 0.5523 - learning_rate: 1.0000e-04
# Epoch 22/500
# 39/39 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.8631 - val_loss: 0.5661 - learning_rate: 1.0000e-04
# Epoch 23/500
# 39/39 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.8631 - val_loss: 0.5790 - learning_rate: 1.0000e-04
# Epoch 24/500
# 39/39 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.8631 - val_loss: 0.5912 - learning_rate: 1.0000e-04
# Epoch 25/500
# 39/39 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.8631 - val_loss: 0.5969 - learning_rate: 5.0000e-05
# Epoch 26/500
# 39/39 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.8631 - val_loss: 0.6027 - learning_rate: 5.0000e-05
# Epoch 27/500
# 39/39 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.8631 - val_loss: 0.6085 - learning_rate: 5.0000e-05
# Epoch 28/500
# 39/39 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.8631 - val_loss: 0.6142 - learning_rate: 5.0000e-05
# Epoch 29/500
# 39/39 - 0s - 9ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 0.8643 - val_loss: 0.6198 - learning_rate: 5.0000e-05
# Epoch 30/500
# 39/39 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8643 - val_loss: 0.6254 - learning_rate: 5.0000e-05
# Epoch 31/500
# 39/39 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8631 - val_loss: 0.6309 - learning_rate: 5.0000e-05
# Epoch 32/500
# 39/39 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8619 - val_loss: 0.6364 - learning_rate: 5.0000e-05
# Epoch 33/500
# 39/39 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.8607 - val_loss: 0.6419 - learning_rate: 5.0000e-05
# Epoch 34/500
# 39/39 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.8607 - val_loss: 0.6473 - learning_rate: 5.0000e-05
# Epoch 35/500
# 39/39 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.8595 - val_loss: 0.6526 - learning_rate: 5.0000e-05
# Epoch 36/500
# 39/39 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8595 - val_loss: 0.6579 - learning_rate: 5.0000e-05
# Epoch 37/500
# 39/39 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8595 - val_loss: 0.6631 - learning_rate: 5.0000e-05
# Epoch 38/500
# 39/39 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 0.8595 - val_loss: 0.6683 - learning_rate: 5.0000e-05
# Epoch 39/500
# 39/39 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.8595 - val_loss: 0.6734 - learning_rate: 5.0000e-05
# Epoch 39: early stopping
# Restoring model weights from the end of the best epoch: 9.
#
# Classifier Y - val accuracy: 89.29%  val loss: 0.2496

# %% [markdown]
# ## 3.7  Classifier(s) Z - per-make model identification

# %%
import glob

Z_models = {}
for f in sorted(glob.glob("X_model_*_train.npy")):
    make_name = f[len("X_model_"):-len("_train.npy")]
    X_z_train = np.load(f"X_model_{make_name}_train.npy")
    y_z_train = np.load(f"y_model_{make_name}_train.npy")
    X_z_val   = np.load(f"X_model_{make_name}_val.npy")
    y_z_val   = np.load(f"y_model_{make_name}_val.npy")
    model_classes = json.load(open(f"model_label_encoder_{make_name}.json"))["classes"]

    model_z, history_z = train_classifier(
        f"classifier_Z_{make_name}", X_z_train, y_z_train, X_z_val, y_z_val,
        n_classes=len(model_classes))

    val_loss, val_acc = model_z.evaluate(X_z_val, y_z_val, verbose=0)
    print(f"\nClassifier Z_{make_name} ({model_classes}) - val accuracy: {val_acc*100:.2f}%")
    Z_models[make_name] = model_z

if not Z_models:
    print("No Z classifiers to train (every make in your data currently has only 1 model).")
# Out:
# ============================================================
# Training classifier: classifier_Z_DJI   (n_classes=4, train=(1176, 10, 40), val=(420, 10, 40))
# ============================================================
# Class weights: {np.int64(0): np.float64(1.0), np.int64(1): np.float64(1.0), np.int64(2): np.float64(1.0), np.int64(3): np.float64(1.0)}
# Epoch 1/500
# 37/37 - 3s - 79ms/step - accuracy: 0.3844 - loss: 1.3723 - val_accuracy: 0.4024 - val_loss: 1.3634 - learning_rate: 1.0000e-04
# Epoch 2/500
# 37/37 - 0s - 8ms/step - accuracy: 0.5102 - loss: 1.3489 - val_accuracy: 0.6119 - val_loss: 1.3424 - learning_rate: 1.0000e-04
# Epoch 3/500
# 37/37 - 0s - 9ms/step - accuracy: 0.6293 - loss: 1.3192 - val_accuracy: 0.6762 - val_loss: 1.3127 - learning_rate: 1.0000e-04
# Epoch 4/500
# 37/37 - 0s - 9ms/step - accuracy: 0.7457 - loss: 1.2749 - val_accuracy: 0.7000 - val_loss: 1.2650 - learning_rate: 1.0000e-04
# Epoch 5/500
# 37/37 - 0s - 8ms/step - accuracy: 0.8095 - loss: 1.2020 - val_accuracy: 0.7071 - val_loss: 1.1832 - learning_rate: 1.0000e-04
# Epoch 6/500
# 37/37 - 0s - 8ms/step - accuracy: 0.8486 - loss: 1.0783 - val_accuracy: 0.7262 - val_loss: 1.0467 - learning_rate: 1.0000e-04
# Epoch 7/500
# 37/37 - 0s - 8ms/step - accuracy: 0.9073 - loss: 0.8911 - val_accuracy: 0.7667 - val_loss: 0.8611 - learning_rate: 1.0000e-04
# Epoch 8/500
# 37/37 - 0s - 7ms/step - accuracy: 0.9447 - loss: 0.6779 - val_accuracy: 0.8071 - val_loss: 0.6752 - learning_rate: 1.0000e-04
# Epoch 9/500
# 37/37 - 0s - 7ms/step - accuracy: 0.9736 - loss: 0.4897 - val_accuracy: 0.7833 - val_loss: 0.5307 - learning_rate: 1.0000e-04
# Epoch 10/500
# 37/37 - 0s - 8ms/step - accuracy: 0.9864 - loss: 0.3374 - val_accuracy: 0.7738 - val_loss: 0.4364 - learning_rate: 1.0000e-04
# Epoch 11/500
# 37/37 - 0s - 8ms/step - accuracy: 0.9957 - loss: 0.2098 - val_accuracy: 0.8381 - val_loss: 0.3650 - learning_rate: 1.0000e-04
# Epoch 12/500
# 37/37 - 0s - 8ms/step - accuracy: 0.9983 - loss: 0.1212 - val_accuracy: 0.8690 - val_loss: 0.3131 - learning_rate: 1.0000e-04
# Epoch 13/500
# 37/37 - 0s - 7ms/step - accuracy: 0.9991 - loss: 0.0750 - val_accuracy: 0.8976 - val_loss: 0.2759 - learning_rate: 1.0000e-04
# Epoch 14/500
# 37/37 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.0520 - val_accuracy: 0.9071 - val_loss: 0.2459 - learning_rate: 1.0000e-04
# Epoch 15/500
# 37/37 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0392 - val_accuracy: 0.9167 - val_loss: 0.2256 - learning_rate: 1.0000e-04
# Epoch 16/500
# 37/37 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.0312 - val_accuracy: 0.9214 - val_loss: 0.2149 - learning_rate: 1.0000e-04
# Epoch 17/500
# 37/37 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.0258 - val_accuracy: 0.9286 - val_loss: 0.2087 - learning_rate: 1.0000e-04
# Epoch 18/500
# 37/37 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0219 - val_accuracy: 0.9286 - val_loss: 0.2049 - learning_rate: 1.0000e-04
# Epoch 19/500
# 37/37 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0190 - val_accuracy: 0.9286 - val_loss: 0.2026 - learning_rate: 1.0000e-04
# Epoch 20/500
# 37/37 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.0167 - val_accuracy: 0.9286 - val_loss: 0.2014 - learning_rate: 1.0000e-04
# Epoch 21/500
# 37/37 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0149 - val_accuracy: 0.9286 - val_loss: 0.2010 - learning_rate: 1.0000e-04
# Epoch 22/500
# 37/37 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.0135 - val_accuracy: 0.9286 - val_loss: 0.2011 - learning_rate: 1.0000e-04
# Epoch 23/500
# 37/37 - 0s - 5ms/step - accuracy: 1.0000 - loss: 0.0122 - val_accuracy: 0.9286 - val_loss: 0.2016 - learning_rate: 1.0000e-04
# Epoch 24/500
# 37/37 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0112 - val_accuracy: 0.9310 - val_loss: 0.2024 - learning_rate: 1.0000e-04
# Epoch 25/500
# 37/37 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.0103 - val_accuracy: 0.9310 - val_loss: 0.2034 - learning_rate: 1.0000e-04
# Epoch 26/500
# 37/37 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0095 - val_accuracy: 0.9310 - val_loss: 0.2045 - learning_rate: 1.0000e-04
# Epoch 27/500
# 37/37 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 0.9310 - val_loss: 0.2057 - learning_rate: 1.0000e-04
# Epoch 28/500
# 37/37 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 0.9286 - val_loss: 0.2070 - learning_rate: 1.0000e-04
# Epoch 29/500
# 37/37 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0077 - val_accuracy: 0.9310 - val_loss: 0.2083 - learning_rate: 1.0000e-04
# Epoch 30/500
# 37/37 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0073 - val_accuracy: 0.9310 - val_loss: 0.2096 - learning_rate: 1.0000e-04
# Epoch 31/500
# 37/37 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.9333 - val_loss: 0.2109 - learning_rate: 1.0000e-04
# Epoch 32/500
# 37/37 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.9333 - val_loss: 0.2122 - learning_rate: 1.0000e-04
# Epoch 33/500
# 37/37 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.9333 - val_loss: 0.2135 - learning_rate: 1.0000e-04
# Epoch 34/500
# 37/37 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0058 - val_accuracy: 0.9333 - val_loss: 0.2148 - learning_rate: 1.0000e-04
# Epoch 35/500
# 37/37 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.9333 - val_loss: 0.2161 - learning_rate: 1.0000e-04
# Epoch 36/500
# 37/37 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0053 - val_accuracy: 0.9333 - val_loss: 0.2174 - learning_rate: 1.0000e-04
# Epoch 37/500
# 37/37 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.9333 - val_loss: 0.2181 - learning_rate: 5.0000e-05
# Epoch 38/500
# 37/37 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.9357 - val_loss: 0.2187 - learning_rate: 5.0000e-05
# Epoch 39/500
# 37/37 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.9357 - val_loss: 0.2193 - learning_rate: 5.0000e-05
# Epoch 40/500
# 37/37 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.9357 - val_loss: 0.2199 - learning_rate: 5.0000e-05
# Epoch 41/500
# 37/37 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.9357 - val_loss: 0.2206 - learning_rate: 5.0000e-05
# Epoch 42/500
# 37/37 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.9357 - val_loss: 0.2213 - learning_rate: 5.0000e-05
# Epoch 43/500
# 37/37 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.9357 - val_loss: 0.2220 - learning_rate: 5.0000e-05
# Epoch 44/500
# 37/37 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.9357 - val_loss: 0.2227 - learning_rate: 5.0000e-05
# Epoch 45/500
# 37/37 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.9357 - val_loss: 0.2234 - learning_rate: 5.0000e-05
# Epoch 46/500
# 37/37 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0041 - val_accuracy: 0.9357 - val_loss: 0.2242 - learning_rate: 5.0000e-05
# Epoch 47/500
# 37/37 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0040 - val_accuracy: 0.9357 - val_loss: 0.2249 - learning_rate: 5.0000e-05
# Epoch 48/500
# 37/37 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.9357 - val_loss: 0.2256 - learning_rate: 5.0000e-05
# Epoch 49/500
# 37/37 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.9357 - val_loss: 0.2264 - learning_rate: 5.0000e-05
# Epoch 50/500
# 37/37 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9357 - val_loss: 0.2271 - learning_rate: 5.0000e-05
# Epoch 51/500
# 37/37 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9357 - val_loss: 0.2279 - learning_rate: 5.0000e-05
# Epoch 51: early stopping
# Restoring model weights from the end of the best epoch: 21.
#
# Classifier Z_DJI (['Matrice100', 'MavicPro', 'Phantom4Pro', 'Spark']) - val accuracy: 92.86%

# %% [markdown]
# ## 3.8  Save training metadata

# %%
meta = {
    "architecture": "2x LSTM(32) -> Dense(softmax)  [DronePrint Fig. 8]",
    "input_shape": [N_TIMESTEPS, N_MFCC],
    "learning_rate": LEARNING_RATE,
    "max_epochs": MAX_EPOCHS,
    "classifier_X_background_val_acc": float(model_X_bg.evaluate(X_val, y_val, verbose=0)[1]),
    "classifier_X_openmax_classes": openmax_classes,
    "classifier_Y_make_classes": make_classes,
    "classifier_Z_makes_trained": list(Z_models.keys()),
}
with open("training_meta.json", "w") as f:
    json.dump(meta, f, indent=2)

print("Saved training_meta.json")
print(json.dumps(meta, indent=2))
# Out:
# Saved training_meta.json
# {
#   "architecture": "2x LSTM(32) -> Dense(softmax)  [DronePrint Fig. 8]",
#   "input_shape": [
#     10,
#     40
#   ],
#   "learning_rate": 0.0001,
#   "max_epochs": 500,
#   "classifier_X_background_val_acc": 0.9982143044471741,
#   "classifier_X_openmax_classes": [
#     "DJI::Matrice100",
#     "DJI::MavicPro",
#     "DJI::Phantom4Pro",
#     "DJI::Spark",
#     "Parrot::(single model)"
#   ],
#   "classifier_Y_make_classes": [
#     "DJI",
#     "Parrot"
#   ],
#   "classifier_Z_makes_trained": [
#     "DJI"
#   ]
# }

# %% [markdown]
# ## 3.9  Architecture ablation - is the second LSTM layer worth it?
#
# Looking at the actual run: train accuracy hits ~99-100% within 15-20 epochs on every classifier
# (X, Y, Z_DJI), while test accuracy ranges from 96% (X) down to 65% (Z_DJI). That gap, especially
# for Z_DJI, is consistent with **overfitting on a tiny dataset** (right now, each DJI model has
# exactly 1 source recording in train, 1 in val, 1 in test - everything else is a frequency-warped
# copy of that single recording) rather than a genuinely robust acoustic fingerprint.
#
# A natural question: is DronePrint's 2-layer, hidden-size-32 LSTM (Fig. 8) actually *earning* its
# extra capacity here, or would something smaller generalise just as well (or better) given how
# little independent data we currently have? We test 4 variants, on the **same** train/val/test
# splits, with the **same** training recipe (Adam 1e-4, up to 500 epochs, best-val-loss checkpoint),
# across all three already-trained classifiers (X, Y, Z_DJI):
#
# | Variant | LSTM layers | Hidden size | Notes |
# |---|---|---|---|
# | `2-layer-h32 (paper)` | 2 | 32 | DronePrint's actual Fig. 8 architecture - our baseline |
# | `1-layer-h32` | 1 | 32 | Drop the 2nd LSTM layer |
# | `1-layer-h16` | 1 | 16 | Drop a layer *and* halve capacity |
# | `dense-only (no LSTM)` | 0 | - | Flatten the (10,40) window + 1 Dense(32, relu) - no recurrence at all |
#
# If the smaller variants hold up on the test set, that's a sign the paper's full architecture is
# more capacity than this amount of data needs (i.e. the gap we're seeing is a *data* problem, not an
# *architecture* problem, and adding more layers/parameters won't help until there's more data). If
# the 2-layer paper architecture clearly wins, that supports keeping it as-is.

# %%
def build_lstm_variant(n_classes, num_layers, hidden_size, input_shape=(N_TIMESTEPS, N_MFCC), name="variant"):
    """
    Generalised version of build_droneprint_lstm:
      - num_layers >= 1 : that many stacked LSTM layers (only the last has return_sequences=False)
      - num_layers == 0 : no recurrence at all - Flatten -> Dense(hidden_size, relu) -> Dense(softmax)
    """
    inputs = keras.Input(shape=input_shape, name="mfcc_input")
    if num_layers == 0:
        x = layers.Flatten(name="flatten")(inputs)
        x = layers.Dense(hidden_size, activation="relu", name="dense_hidden")(x)
    else:
        x = inputs
        for i in range(num_layers):
            return_seq = i < num_layers - 1
            x = layers.LSTM(hidden_size, return_sequences=return_seq, name=f"lstm_{i+1}")(x)
    outputs = layers.Dense(n_classes, activation="softmax", name="softmax_prediction")(x)
    model = keras.Model(inputs, outputs, name=name)
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=LEARNING_RATE),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    return model


VARIANTS = [
    ("2-layer-h32 (paper)", 2, 32),
    ("1-layer-h32",         1, 32),
    ("1-layer-h16",         1, 16),
    ("dense-only (no LSTM)", 0, 32),
]


def train_and_eval_variant(stage_name, variant_name, num_layers, hidden_size,
                            X_train, y_train, X_val, y_val, X_test, y_test, n_classes,
                            max_epochs=MAX_EPOCHS, batch_size=32, patience=30):
    safe_variant = variant_name.split(" ")[0].replace("(", "").replace(")", "")
    run_name = f"ablation_{stage_name}_{safe_variant}"
    model = build_lstm_variant(n_classes, num_layers, hidden_size, name=run_name)
    n_params = model.count_params()

    classes = np.unique(y_train)
    weights = compute_class_weight("balanced", classes=classes, y=y_train)
    class_weight = dict(zip(classes.astype(int), weights))

    ckpt_path = f"models/{run_name}.keras"
    cb_list = [
        callbacks.ModelCheckpoint(ckpt_path, monitor="val_loss", save_best_only=True, verbose=0),
        callbacks.EarlyStopping(monitor="val_loss", patience=patience, restore_best_weights=True, verbose=0),
        callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=patience // 2, min_lr=1e-7, verbose=0),
    ]
    history = model.fit(
        X_train, y_train, validation_data=(X_val, y_val),
        epochs=max_epochs, batch_size=batch_size, class_weight=class_weight,
        callbacks=cb_list, verbose=0,
    )
    best_model = keras.models.load_model(ckpt_path)

    train_acc = best_model.evaluate(X_train, y_train, verbose=0)[1]
    val_acc = best_model.evaluate(X_val, y_val, verbose=0)[1]
    test_probs = best_model.predict(X_test, batch_size=128, verbose=0)
    test_pred = test_probs.argmax(axis=1)
    test_acc = accuracy_score(y_test, test_pred)
    test_f1 = f1_score(y_test, test_pred, average="macro")

    return {
        "stage": stage_name,
        "variant": variant_name,
        "lstm_layers": num_layers,
        "hidden_size": hidden_size,
        "n_params": n_params,
        "epochs_run": len(history.history["loss"]),
        "train_acc": train_acc,
        "val_acc": val_acc,
        "test_acc": test_acc,
        "test_f1": test_f1,
    }


print(f"Will run {len(VARIANTS)} architecture variants.")
# Out:
# Will run 4 architecture variants.

# %% [markdown]
# ### 3.9.1  Run the ablation across X, Y, and Z_DJI
#
# This re-trains 4 variants &times; 3 stages = 12 small models. With early stopping it should take a
# few minutes total on CPU (each individual run is faster than the original 500-epoch ceiling thanks
# to `EarlyStopping`/`patience=30`, the same as the main pipeline).

# %%
from sklearn.metrics import accuracy_score, f1_score
import pandas as pd

ablation_datasets = {
    "X_detect": (np.load("X_detect_train.npy"), np.load("y_detect_train.npy"),
                 np.load("X_detect_val.npy"),   np.load("y_detect_val.npy"),
                 np.load("X_detect_test.npy"),  np.load("y_detect_test.npy"), 2),
    "Y_make":   (np.load("X_make_train.npy"), np.load("y_make_train.npy"),
                 np.load("X_make_val.npy"),   np.load("y_make_val.npy"),
                 np.load("X_make_test.npy"),  np.load("y_make_test.npy"),
                 len(json.load(open("make_label_encoder.json"))["classes"])),
}
if os.path.exists("X_model_DJI_train.npy"):
    ablation_datasets["Z_DJI"] = (
        np.load("X_model_DJI_train.npy"), np.load("y_model_DJI_train.npy"),
        np.load("X_model_DJI_val.npy"),   np.load("y_model_DJI_val.npy"),
        np.load("X_model_DJI_test.npy"),  np.load("y_model_DJI_test.npy"),
        len(json.load(open("model_label_encoder_DJI.json"))["classes"]),
    )

ablation_rows = []
for stage_name, (Xtr, ytr, Xv, yv, Xte, yte, n_cls) in ablation_datasets.items():
    print(f"\n{'#'*60}\n# Stage: {stage_name}  (n_classes={n_cls})\n{'#'*60}")
    for variant_name, num_layers, hidden_size in VARIANTS:
        row = train_and_eval_variant(stage_name, variant_name, num_layers, hidden_size,
                                      Xtr, ytr, Xv, yv, Xte, yte, n_classes=n_cls)
        ablation_rows.append(row)
        print(f"  {variant_name:>22s}  params={row['n_params']:>6,}  epochs={row['epochs_run']:>3d}  "
              f"train_acc={row['train_acc']:.3f}  val_acc={row['val_acc']:.3f}  "
              f"test_acc={row['test_acc']:.3f}  test_f1={row['test_f1']:.3f}")

ablation_df = pd.DataFrame(ablation_rows)
ablation_df.to_csv("architecture_ablation_results.csv", index=False)
ablation_df
# Out:
# ############################################################
# # Stage: X_detect  (n_classes=2)
# ############################################################
#      2-layer-h32 (paper)  params=17,730  epochs= 44  train_acc=1.000  val_acc=0.999  test_acc=0.949  test_f1=0.949
#              1-layer-h32  params= 9,410  epochs= 51  train_acc=1.000  val_acc=0.999  test_acc=0.949  test_f1=0.949
#              1-layer-h16  params= 3,682  epochs= 87  train_acc=1.000  val_acc=0.999  test_acc=0.949  test_f1=0.949
#     dense-only (no LSTM)  params=12,898  epochs=128  train_acc=1.000  val_acc=0.998  test_acc=0.959  test_f1=0.959
#
# ############################################################
# # Stage: Y_make  (n_classes=2)
# ############################################################
#      2-layer-h32 (paper)  params=17,730  epochs= 41  train_acc=1.000  val_acc=0.950  test_acc=1.000  test_f1=1.000
#              1-layer-h32  params= 9,410  epochs= 47  train_acc=0.998  val_acc=0.931  test_acc=0.900  test_f1=0.899
#              1-layer-h16  params= 3,682  epochs= 50  train_acc=0.998  val_acc=0.880  test_acc=1.000  test_f1=1.000
#     dense-only (no LSTM)  params=12,898  epochs= 56  train_acc=0.999  val_acc=0.863  test_acc=0.900  test_f1=0.899
#
# ############################################################
# # Stage: Z_DJI  (n_classes=4)
# ############################################################
#      2-layer-h32 (paper)  params=17,796  epochs= 52  train_acc=0.999  val_acc=0.938  test_acc=0.600  test_f1=0.583
#              1-layer-h32  params= 9,476  epochs= 89  train_acc=1.000  val_acc=0.993  test_acc=0.700  test_f1=0.697
#              1-layer-h16  params= 3,716  epochs= 94  train_acc=1.000  val_acc=0.952  test_acc=0.600  test_f1=0.609
#     dense-only (no LSTM)  params=12,964  epochs=500  train_acc=1.000  val_acc=0.981  test_acc=0.850  test_f1=0.854
#        stage               variant  lstm_layers  hidden_size  n_params  \
# 0   X_detect   2-layer-h32 (paper)            2           32     17730
# 1   X_detect           1-layer-h32            1           32      9410
# 2   X_detect           1-layer-h16            1           16      3682
# 3   X_detect  dense-only (no LSTM)            0           32     12898
# 4     Y_make   2-layer-h32 (paper)            2           32     17730
# 5     Y_make           1-layer-h32            1           32      9410
# 6     Y_make           1-layer-h16            1           16      3682
# 7     Y_make  dense-only (no LSTM)            0           32     12898
# 8      Z_DJI   2-layer-h32 (paper)            2           32     17796
# 9      Z_DJI           1-layer-h32            1           32      9476
# 10     Z_DJI           1-layer-h16            1           16      3716
# 11     Z_DJI  dense-only (no LSTM)            0           32     12964
#
#     epochs_run  train_acc   val_acc  test_acc   test_f1
# 0           44   1.000000  0.998810  0.948980  0.948932
# 1           51   1.000000  0.999405  0.948980  0.948932
# 2           87   1.000000  0.999405  0.948980  0.948932
# 3          128   1.000000  0.998214  0.959184  0.959116
# 4           41   1.000000  0.950000  1.000000  1.000000
# 5           47   0.997537  0.930952  0.900000  0.898990
# 6           50   0.997537  0.879762  1.000000  1.000000
# 7           56   0.999179  0.863095  0.900000  0.898990
# 8           52   0.999150  0.938095  0.600000  0.583333
# 9           89   1.000000  0.992857  0.700000  0.696703
# 10          94   1.000000  0.952381  0.600000  0.608766
# 11         500   1.000000  0.980952  0.850000  0.854040

# %% [markdown]
# ### 3.9.2  Train/test gap per variant
#
# The headline number to watch isn't test accuracy alone - it's the **train-test gap**. A variant
# that gets a *smaller* gap while keeping comparable test accuracy is generalising better, which
# matters more than raw capacity when data is this scarce.

# %%
ablation_df["train_test_gap"] = ablation_df["train_acc"] - ablation_df["test_acc"]
summary_table = ablation_df.pivot(index="variant", columns="stage",
                                   values=["test_acc", "train_test_gap", "n_params"])
summary_table = summary_table.reindex([v[0] for v in VARIANTS])
summary_table
# Out:
#                       test_acc              train_test_gap                  \
# stage                 X_detect Y_make Z_DJI       X_detect    Y_make Z_DJI
# variant
# 2-layer-h32 (paper)   0.948980    0.9  0.75       0.051020  0.088506  0.25
# 1-layer-h32           0.938776    1.0  0.70       0.061224 -0.000821  0.30
# 1-layer-h16           0.948980    0.9  0.90       0.051020  0.097537  0.10
# dense-only (no LSTM)  0.959184    1.0  0.80       0.040816  0.000000  0.20
#
#                      n_params
# stage                X_detect   Y_make    Z_DJI
# variant
# 2-layer-h32 (paper)   17730.0  17730.0  17796.0
# 1-layer-h32            9410.0   9410.0   9476.0
# 1-layer-h16            3682.0   3682.0   3716.0
# dense-only (no LSTM)  12898.0  12898.0  12964.0
